-- %%
--=====================================================================================
-- SCHEMA CREATION
--=====================================================================================
 
CREATE CATALOG IF NOT EXISTS q_chem_poc_uc;
 
CREATE SCHEMA IF NOT EXISTS q_chem_poc_uc.Gold
COMMENT 'Gold layer for q_chem_poc_uc DWH: curated star schemas for CEO (EMRS) and Safety (QSAFE) dashboards';
 
USE CATALOG q_chem_poc_uc;
USE SCHEMA Gold;
