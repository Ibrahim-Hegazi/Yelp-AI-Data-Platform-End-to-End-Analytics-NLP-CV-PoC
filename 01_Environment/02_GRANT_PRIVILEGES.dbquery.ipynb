-- %%
--=====================================================================================
-- GRANT PRIVILEGES ON CATALOG
--=====================================================================================

GRANT ALL PRIVILEGES ON CATALOG yelp_poc_uc TO `ibrahim.mohamed@gbrands.com`;

--=====================================================================================
-- GRANT PRIVILEGES ON SCHEMAS (Bronze, Silver, Gold)
--=====================================================================================

GRANT ALL PRIVILEGES ON SCHEMA yelp_poc_uc.Bronze TO `ibrahim.mohamed@gbrands.com`;
GRANT ALL PRIVILEGES ON SCHEMA yelp_poc_uc.Silver TO `ibrahim.mohamed@gbrands.com`;
GRANT ALL PRIVILEGES ON SCHEMA yelp_poc_uc.Gold TO `ibrahim.mohamed@gbrands.com`;

--=====================================================================================
-- GRANT PRIVILEGES ON VOLUMES
--=====================================================================================

GRANT ALL PRIVILEGES ON VOLUME yelp_poc_uc.bronze.landing_zone TO `ibrahim.mohamed@gbrands.com`;
GRANT ALL PRIVILEGES ON VOLUME yelp_poc_uc.bronze.validated_schema_zone TO `ibrahim.mohamed@gbrands.com`;
